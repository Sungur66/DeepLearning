# %% [markdown]
# <p style="background-color:#3ab1c8;font-family:Cursive;font-size:200%;color:black;text-align:center;border-radius:120px 20px;padding:20px;margin:20px;"><b>OCT 2017 - Eye Project</b></p>
#
# <p style="font-family:Cursive;font-size:100%;color:black;text-align:center;border-radius:10px 10px;"><b>by Nash</b></p>
#
# <b style="font-family:Cursive;font-size:100%;color:black;text-align:right;border-radius:10px 10px;">Follow me [Linkedin](www.linkedin.com/in/nash-n-sungur-333869289) | [Git Hub](https://api.whatsapp.com/send/?phone=%2B15853042959&text&type=phone_number&app_absent=0)</b>

# %%
import os
import pandas as pd
import tensorflow as tf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread

# %matplotlib inline
# %matplotlib notebook
plt.rcParams["figure.figsize"] = (12, 6)
# plt.rcParams['figure.dpi'] = 100
sns.set_style("whitegrid")
import warnings

warnings.filterwarnings("ignore")
warnings.warn("this will not show")
pd.set_option('display.float_format', lambda x: '%.3f' % x)
# Out:
# C:\Users\nsgr6\AppData\Roaming\Python\Python310\site-packages\matplotlib\projections\__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
my_data_dir='OCT2017/'

# %%
os.listdir(my_data_dir)
# Out:
# ['test', 'train']

# %%
train_path = my_data_dir+'train'
test_path = my_data_dir+'test'

# %%
os.listdir(train_path)
# Out:
# ['CNV', 'DME', 'DRUSEN', 'NORMAL']

# %%
# The number of images in Train folder

print(len(os.listdir(train_path+'/CNV')), '-',
      len(os.listdir(train_path+'/DME')), '-',
      len(os.listdir(train_path+'/DRUSEN')), '-',
      len(os.listdir(train_path+'/NORMAL')))
# Out:
# 37205 - 11348 - 8616 - 26315

# %%
print(os.listdir(train_path+'/CNV')[20], '\n',
        os.listdir(train_path+'/DME')[20], '\n',
        os.listdir(train_path+'/DRUSEN')[20], '\n',
        os.listdir(train_path+'/NORMAL')[20])
# Out:
# CNV-1016042-117.jpeg
#  DME-1141111-2.jpeg
#  DRUSEN-1020679-2.jpeg
#  NORMAL-1004480-7.jpeg

# %%
path1=train_path+'/CNV'+'/CNV-1016042-117.jpeg '
path2=train_path+'/DME'+'/DME-1141111-2.jpeg'
path3=train_path+'/DRUSEN'+'/DRUSEN-1020679-2.jpeg'
path4=train_path+'/NORMAL'+'/NORMAL-1004480-7.jpeg'

# %%
CNV_image = imread(path1)

# %%
plt.imshow(CNV_image);

# %%
print(CNV_image.max(), '&', CNV_image.min(), '&', CNV_image.shape)
# Out:
# 255 & 0 & (496, 512)

# %%
DME_image = imread(path2)

# %%
plt.imshow(DME_image);

# %%
print(DME_image.max(), '&', DME_image.min(), '&', DME_image.shape)
# Out:
# 255 & 0 & (496, 512)

# %%
DRUSEN_image = imread(path3)

# %%
plt.imshow(DRUSEN_image);

# %%
print(DRUSEN_image.max(), '&', DRUSEN_image.min(), '&', DRUSEN_image.shape)
# Out:
# 255 & 0 & (496, 512)

# %%
NORMAL_image = imread(path4)

# %%
plt.imshow(NORMAL_image);

# %%
print(NORMAL_image.max(), '&', NORMAL_image.min(), '&', NORMAL_image.shape)
# Out:
# 255 & 0 & (496, 768)

# %%
#dimensions of CNV

# x= []
# y = []
# for image in os.listdir(train_path+'/CNV'):
    
#     img = imread(train_path+'/CNV/'+image)
#     d1,d2 = img.shape
#     x.append(d1)
#     y.append(d2)
     
# sns.scatterplot(x=x,y=y);

# %%
#np.mean(x), np.mean(y)

# %%
# dimensions of DME

# x= []
# y = []
# for image in os.listdir(train_path+'/DME'):
    
#     img = imread(train_path+'/DME/'+image)
#     d1,d2 = img.shape
#     x.append(d1)
#     y.append(d2)
    
# sns.scatterplot(x=x,y=y);

# %%
#np.mean(x), np.mean(y)

# %%
# dimensions of DME

# x= []
# y = []
# for image in os.listdir(train_path+'/DRUSEN'):
    
#     img = imread(train_path+'/DRUSEN/'+image)
#     d1,d2 = img.shape
#     x.append(d1)
#     y.append(d2)
    
# sns.scatterplot(x=x,y=y);

# %%
#np.mean(x), np.mean(y)

# %%
# dimensions of DME

# x= []
# y = []
# for image in os.listdir(train_path+'/NORMAL'):
    
#     img = imread(train_path+'/NORMAL/'+image)
#     d1,d2 = img.shape
#     x.append(d1)
#     y.append(d2)
    
# sns.scatterplot(x=x,y=y);

# %%
#np.mean(x), np.mean(y)

# %%
# dimensons expention for image manipulation, for grey scale images
# HER CALISTIGINDA YENI BIR BOYUT EKLER!

CNV_image = np.expand_dims(CNV_image, axis=-1)
DME_image = np.expand_dims(DME_image, axis=-1)
DRUSEN_image = np.expand_dims(DRUSEN_image, axis=-1)
NORMAL_image = np.expand_dims(NORMAL_image, axis=-1)

image_shape = (500, 500, 1)

# %%
# Image manipulation

from tensorflow.keras.preprocessing.image import ImageDataGenerator

image_gen = ImageDataGenerator(rotation_range=20, # rotate the image 20 degrees
                               width_shift_range=0.10, # Shift the pic width by a max of 10%
                               height_shift_range=0.10, # Shift the pic height by a max of 10%
                               rescale=1/255, # Rescale the image by normalzing it.
                               shear_range=0.1, # Shear means cutting away part of the image (max 10%)
                               zoom_range=0.1, # Zoom in by 10% max
                               horizontal_flip=True, # Allo horizontal flipping
                               fill_mode='nearest' # Fill in missing pixels with the nearest filled value
                              )

# %%
plt.imshow(image_gen.random_transform(DRUSEN_image));

# %% [markdown]
# # Creating the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D, BatchNormalization
from tensorflow.keras.applications.resnet import ResNet152, preprocess_input, decode_predictions

# %%
resnet_model = Sequential()

pretrained_model= tf.keras.applications.ResNet152(include_top=False,
                   input_shape=image_shape,
                   pooling='avg',
                   weights= None)
for layer in pretrained_model.layers:
        layer.trainable=False

resnet_model.add(pretrained_model)
resnet_model.add(Flatten())
resnet_model.add(Dense(512, activation='relu'))
resnet_model.add(Dense(4, activation='softmax'))

resnet_model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
resnet_model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━┓
# ┃ Layer (type)                       ┃ Output Shape                  ┃     Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━┩
# │ resnet152 (Functional)             │ ?                             │  58,364,672 │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ flatten (Flatten)                  │ ?                             │ 0 (unbuilt) │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ dense (Dense)                      │ ?                             │ 0 (unbuilt) │
# ├────────────────────────────────────┼───────────────────────────────┼─────────────┤
# │ dense_1 (Dense)                    │ ?                             │ 0 (unbuilt) │
# └────────────────────────────────────┴───────────────────────────────┴─────────────┘
# ...

# %% [markdown]
# ## Early Stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
#early_stop = EarlyStopping(monitor='val_loss',patience=10)

early_stop = EarlyStopping(monitor='val_loss', patience=3, mode='min', verbose=1)

# %%
batch_size = 128

# %%
train_image_gen = image_gen.flow_from_directory(train_path,
                                               target_size=(500,500),
                                                color_mode='grayscale',
                                               batch_size=batch_size,
                                               class_mode='categorical', 
                                                shuffle=True)
# Out:
# Found 83484 images belonging to 4 classes.

# %%
test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=(500,500),
                                               color_mode='grayscale',
                                               batch_size=batch_size,
                                               class_mode='categorical',
                                               shuffle=True)
# Out:
# Found 1000 images belonging to 4 classes.

# %% [markdown]
# ## Model Training

# %%
results = resnet_model.fit(train_image_gen,epochs=2,
                    validation_data=test_image_gen,
                    callbacks=[early_stop], verbose=1)
# Out:
# Epoch 1/2
# 123/653 ━━━━━━━━━━━━━━━━━━━━ 14:35:14 99s/step - accuracy: 0.4191 - loss: 1.2647
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 results = resnet_model.fit(train_image_gen,epochs=2,
#       2                     validation_data=test_image_gen,
#       3                     callbacks=[early_stop], verbose=1)
#
# File ~\.conda\envs\myenv\lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %% [markdown]
# # Evaluating the Model

# %%
model.evaluate(val_image_gen)
# Out:
# 71/71 [==============================] - 33s 464ms/step - loss: 0.3347 - accuracy: 0.8530
# [0.33466219902038574, 0.8529929518699646]

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(test_image_gen.classes,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.86      0.86      1219
#            1       0.84      0.84      0.84      1071
#
#     accuracy                           0.85      2290
#    macro avg       0.85      0.85      0.85      2290
# weighted avg       0.85      0.85      0.85      2290

# %%
confusion_matrix(test_image_gen.classes,predictions)
# Out:
# array([[1051,  168],
#        [ 176,  895]])

# %%
summary = pd.DataFrame(model.history.history)
summary.head()

# %%
plt.figure(figsize=(10,6))
plt.plot(summary.loss, label="loss")
plt.plot(summary.val_loss, label="val_loss")
plt.legend(loc="upper right")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.show()

# %%
# öneri

y_pred = model.predict(test_image_gen).argmax(axis=1)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %%
from tensorflow.keras.models import load_model
model.save('OCT2017_nash.h5')
